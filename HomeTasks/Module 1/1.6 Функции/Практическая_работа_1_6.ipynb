# %% [markdown]
# # 1.6 Функции

# %% [markdown]
# **Решение задачи на числа Фибоначчи рекурсией и циклом**.
#
# Числа Фибоначчи  с успехом были использованы для компьютерных игр. Так компания Acornsoft в 1984 году выпустила игру [Elite](https://habr.com/ru/post/714118/) где 282 000 000 000 000 (двести восемьдесят два миллиона миллионов) галактик создавались с помощью последовательности Фибоначчи.
#
# Эта последовательность может быть получена разными способами. Мы сделаем это с помощью рекурсии, с помощью циклов for и while, а затем упакуем наш скрипт в созданную функцию для удобного дальнейшего использования.

# %%
def fibonacci(n):
    if n in (1, 2):
        return 1
    return fibonacci(n - 1) + fibonacci(n - 2)


print(fibonacci(10))
# Out:
# 55

# %%
fib1 = fib2 = 1

n = int(input())

print(fib1, fib2, end=' ')

for i in range(2, n):
    fib1, fib2 = fib2, fib1 + fib2
    print(fib2, end=' ')
# Out:
# 1 1 3 4 6 9 14 22 35 56 90 145 234 378 611 988 1598 2585 4182 6766 10947 17712 28658 46369 75026 121394 196419 317812 514230 832041 1346270 2178310 3524579 5702888 9227466 14930353 24157818 39088170 63245987 102334156 165580142 267914297 433494438 701408734 1134903171 1836311904 2971215074 4807526977 7778742050 12586269026 20365011075 32951280100 53316291174 86267571273 139583862446 225851433718 365435296163 591286729880 956722026042 1548008755921 2504730781962 4052739537882 6557470319843 10610209857724 17167680177566 27777890035289 44945570212854 72723460248142 117669030460995 190392490709136 308061521170130 498454011879265 806515533049394 1304969544928658 2111485077978051 3416454622906708 5527939700884758 8944394323791465 14472334024676222 23416728348467686 37889062373143907 61305790721611592 99194853094755498 160500643816367089 259695496911122586 420196140727489674 679891637638612259 1100087778366101932 1779979416004714190 2880067194370816121 4660046610375530310 7540113804746346430 12200160415121876739 19740274219868223168 31940434634990099906 51680708854858323073 83621143489848422978 135301852344706746050 218922995834555169027 354224848179261915076

# %%
fib1 = fib2 = 1

n = input("Номер элемента ряда Фибоначчи: ")
n = int(n) - 2

while n > 0:
    fib1, fib2 = fib2, fib1 + fib2
    n -= 1

    print("Значение этого элемента:", fib2)
# Out:
# Значение этого элемента: 2
# Значение этого элемента: 3
# Значение этого элемента: 5
# Значение этого элемента: 8
# Значение этого элемента: 13
# Значение этого элемента: 21
# Значение этого элемента: 34
# Значение этого элемента: 55
# Значение этого элемента: 89
# Значение этого элемента: 144
# Значение этого элемента: 233
# Значение этого элемента: 377
# Значение этого элемента: 610
# Значение этого элемента: 987
# Значение этого элемента: 1597
# Значение этого элемента: 2584
# Значение этого элемента: 4181
# Значение этого элемента: 6765
# Значение этого элемента: 10946
# Значение этого элемента: 17711
# Значение этого элемента: 28657
# Значение этого элемента: 46368
# Значение этого элемента: 75025
# Значение этого элемента: 121393
# Значение этого элемента: 196418
# Значение этого элемента: 317811
# Значение этого элемента: 514229
# Значение этого элемента: 832040
# Значение этого элемента: 1346269
# Значение этого элемента: 2178309
# Значение этого элемента: 3524578
# Значение этого элемента: 5702887
# Значение этого элемента: 9227465
# Значение этого элемента: 14930352
# Значение этого элемента: 24157817
# Значение этого элемента: 39088169
# Значение этого элемента: 63245986
# Значение этого элемента: 102334155
# Значение этого элемента: 165580141
# Значение этого элемента: 267914296
# Значение этого элемента: 433494437
# Значение этого элемента: 701408733
# Значение этого элемента: 1134903170
# Значение этого элемента: 1836311903
# Значение этого элемента: 2971215073
# Значение этого элемента: 4807526976
# Значение этого элемента: 7778742049
# Значение этого элемента: 12586269025
# Значение этого элемента: 20365011074
# Значение этого элемента: 32951280099
# Значение этого элемента: 53316291173

# %%
a = int(input('Номер элемента ряда Фибоначчи = '))

def fib(n):
    a, b = 1, 1
    for _ in range(n):
        yield a
        a, b = b, a + b

print(list(fib(a)))
# Out:
# [1, 1, 2]
